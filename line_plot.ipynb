# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10, 20, 30, 40], marker="o")
plt.show()

# %%
year = [2000, 2001, 2002, 2003, 2004, 2005]
unemply = [9.1, 9.4, 9.0, 9.5, 9.8, 9.9]
plt.plot(year,unemply,marker="o")
plt.xlabel("year")
plt.ylabel("unemply")
plt.show()
